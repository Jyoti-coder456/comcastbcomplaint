# %%
import pandas as pd
import numpy as np

# %%
display(pd.read_csv('Comcast_telecom_complaints_data.csv', nrows=10).head())
# Out:
#    Ticket #                                 Customer Complaint      Date  \
# 0    250635                      Comcast Cable Internet Speeds  22-04-15
# 1    223441       Payment disappear - service got disconnected  04-08-15
# 2    242732                                  Speed and Service  18-04-15
# 3    277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4    307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
df = pd.read_csv('Comcast_telecom_complaints_data.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6      361148      Throttling service and unreasonable data caps  24-06-15
# 7      359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8      318072                           Comcast extended outages  06-01-15
# 9      371214  Comcast Raising Prices and Not Being Available...  28-06-15
# 10     255938  Billing after service was asked to be disconne...  24-04-15
# ...

# %%
df.shape
# Out:
# (2224, 11)

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
from io import StringIO

col = ['Status', 'Customer Complaint']
col
# Out:
# ['Status', 'Customer Complaint']

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
complaint_status = pd.read_csv('Comcast_telecom_complaints_data.csv', index_col=0)
complaint_status.describe
# Out:
# <bound method NDFrame.describe of                                          Customer Complaint      Date  \
# Ticket #
# 250635                        Comcast Cable Internet Speeds  22-04-15
# 223441         Payment disappear - service got disconnected  04-08-15
# 242732                                    Speed and Service  18-04-15
# 277946    Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 307175           Comcast not working and no service to boot  26-05-15
# 338519    ISP Charging for arbitrary data limits with ov...  06-12-15
# 361148        Throttling service and unreasonable data caps  24-06-15
# 359792    Comcast refuses to help troubleshoot and corre...  23-06-15
# 318072                             Comcast extended outages  06-01-15
# 371214    Comcast Raising Prices and Not Being Available...  28-06-15
# 255938    Billing after service was asked to be disconne...  24-04-15
# 276409        YAHOO FAILURE TO RESTORE EMAIL SEARCH FEATURE  05-06-15
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
complaint_tab = pd.crosstab(index= complaint_status["Customer Complaint"], columns="count" )  
complaint_tab
# Out:
# col_0                                               count
# Customer Complaint
# (Comcast is not my complaint!) Cyber Tele-marke...      1
# 10 Days No Service - 12 Appointments Comcast Ha...      1
# 2 months and Comcast has not fixed problem              1
# 2+ Day Degraded Services                                1
# 300 GB monthly allowance                                1
# 300 gb cap                                              1
# 300GB/month Data Cap                                    1
# 300GB/month data cap 'trial' for several years now      1
# 60 day delay in cancelling service agreement            1
# 60 days to close my account                             1
# 95 Palmer Road, Enfield NH Internet Pricing             1
# AT&T                                                    1
# About Comcast                                           1
# Abysmal customer service, do not approve merger...      1
# Access issues have returned                             1
# ...

# %%
complaint_tab.count
# Out:
# <bound method DataFrame.count of col_0                                               count
# Customer Complaint
# (Comcast is not my complaint!) Cyber Tele-marke...      1
# 10 Days No Service - 12 Appointments Comcast Ha...      1
# 2 months and Comcast has not fixed problem              1
# 2+ Day Degraded Services                                1
# 300 GB monthly allowance                                1
# 300 gb cap                                              1
# 300GB/month Data Cap                                    1
# 300GB/month data cap 'trial' for several years now      1
# 60 day delay in cancelling service agreement            1
# 60 days to close my account                             1
# 95 Palmer Road, Enfield NH Internet Pricing             1
# AT&T                                                    1
# About Comcast                                           1
# Abysmal customer service, do not approve merger...      1
# ...

# %%
complaint_tab.filter(['State','Status'])
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
complaint_tab = pd.crosstab(index=complaint_status["Status"], columns="count")  
complaint_tab
# Out:
# col_0    count
# Status
# Closed     734
# Open       363
# Pending    154
# Solved     973

# %%
df = pd.read_csv("Comcast_telecom_complaints_data.csv") 
df
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6      361148      Throttling service and unreasonable data caps  24-06-15
# 7      359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8      318072                           Comcast extended outages  06-01-15
# 9      371214  Comcast Raising Prices and Not Being Available...  28-06-15
# 10     255938  Billing after service was asked to be disconne...  24-04-15
# ...

# %%
df.replace (to_replace =["Pending","Solved"] , value =["Open","Closed"])
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6      361148      Throttling service and unreasonable data caps  24-06-15
# 7      359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8      318072                           Comcast extended outages  06-01-15
# 9      371214  Comcast Raising Prices and Not Being Available...  28-06-15
# 10     255938  Billing after service was asked to be disconne...  24-04-15
# ...

# %%
df.groupby('State')['Status'].nunique().plot(kind='bar')
plt.show()

# %%
df.groupby(['State','Status'])['Customer Complaint'].max()
# Out:
# State                 Status
# Alabama               Closed                                     i need help pleas
#                       Open                                        Xfinity Data Cap
#                       Pending                                      Overage Charges
#                       Solved                                     monthly data caps
# Arizona               Closed     comcast is changing my paper bill to ecobill w...
#                       Open                                               Data Caps
#                       Pending         Tucson Comcast Data Caps on Internet Service
#                       Solved                             Improper Billing/Services
# Arkansas              Closed                     Ongoing Comcast internet outages.
#                       Solved                                      xfinity Internet
# California            Closed                       recent hacking of email account
# ...

# %% [markdown]
# # Which state has the highest percentage of unresolved complaints

# %%
c = df.State

# %%
counts = c.value_counts()
counts
# Out:
# Georgia                 288
# Florida                 240
# California              220
# Illinois                164
# Tennessee               143
# Pennsylvania            130
# Michigan                115
# Washington               98
# Colorado                 80
# Maryland                 78
# New Jersey               75
# Texas                    71
# Massachusetts            61
# Virginia                 60
# Indiana                  59
# Oregon                   49
# Mississippi              39
# Minnesota                33
# Alabama                  26
# Utah                     22
# Arizona                  20
# South Carolina           18
# District Of Columbia     16
# New Mexico               15
# Louisiana                13
# Connecticut              12
# Delaware                 12
# New Hampshire            12
# West Virginia            11
# Kentucky                  7
# New York                  6
# Arkansas                  6
# Maine                     5
# ...

# %%
percent = c.value_counts( normalize = True)
percent
# Out:
# Georgia                 0.129496
# Florida                 0.107914
# California              0.098921
# Illinois                0.073741
# Tennessee               0.064299
# Pennsylvania            0.058453
# Michigan                0.051709
# Washington              0.044065
# Colorado                0.035971
# Maryland                0.035072
# New Jersey              0.033723
# Texas                   0.031924
# Massachusetts           0.027428
# Virginia                0.026978
# Indiana                 0.026529
# Oregon                  0.022032
# Mississippi             0.017536
# Minnesota               0.014838
# Alabama                 0.011691
# Utah                    0.009892
# Arizona                 0.008993
# South Carolina          0.008094
# District Of Columbia    0.007194
# New Mexico              0.006745
# Louisiana               0.005845
# Connecticut             0.005396
# Delaware                0.005396
# New Hampshire           0.005396
# ...

# %%
percent100 = percent.mul(100).round(1).astype(str) +'%'
percent100
# Out:
# Georgia                 12.9%
# Florida                 10.8%
# California               9.9%
# Illinois                 7.4%
# Tennessee                6.4%
# Pennsylvania             5.8%
# Michigan                 5.2%
# Washington               4.4%
# Colorado                 3.6%
# Maryland                 3.5%
# New Jersey               3.4%
# Texas                    3.2%
# Massachusetts            2.7%
# Virginia                 2.7%
# Indiana                  2.7%
# Oregon                   2.2%
# Mississippi              1.8%
# Minnesota                1.5%
# Alabama                  1.2%
# Utah                     1.0%
# Arizona                  0.9%
# South Carolina           0.8%
# District Of Columbia     0.7%
# New Mexico               0.7%
# Louisiana                0.6%
# Connecticut              0.5%
# Delaware                 0.5%
# New Hampshire            0.5%
# West Virginia            0.5%
# Kentucky                 0.3%
# New York                 0.3%
# ...

# %%
df1 = df.replace (to_replace =["Pending","Solved"] , value =["Open","Closed"])
df1
# Out:
#      Ticket #                                 Customer Complaint      Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-15
# 1      223441       Payment disappear - service got disconnected  04-08-15
# 2      242732                                  Speed and Service  18-04-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4      307175         Comcast not working and no service to boot  26-05-15
# 5      338519  ISP Charging for arbitrary data limits with ov...  06-12-15
# 6      361148      Throttling service and unreasonable data caps  24-06-15
# 7      359792  Comcast refuses to help troubleshoot and corre...  23-06-15
# 8      318072                           Comcast extended outages  06-01-15
# 9      371214  Comcast Raising Prices and Not Being Available...  28-06-15
# 10     255938  Billing after service was asked to be disconne...  24-04-15
# ...

# %%
s=df1.Status

# %%
counts = s.value_counts()
counts
# Out:
# Closed    1707
# Open       517
# Name: Status, dtype: int64

# %%
percent = s.value_counts( normalize = True)
percent
# Out:
# Closed    0.767536
# Open      0.232464
# Name: Status, dtype: float64

# %%
percent100 = percent.mul(100).round(1).astype(str) +'%'
percent100
# Out:
# Closed    76.8%
# Open      23.2%
# Name: Status, dtype: object

# %%
df.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# ...

# %%
df.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Date_month_year', 'Time',
#        'Received Via', 'City', 'State', 'Zip code', 'Status',
#        'Filing on Behalf of Someone'],
#       dtype='object')

# %% [markdown]
# # percentage of complaints resolved till date, which were received through the Internet and customer care calls.

# %%
r = df['Received Via']

# %%
counts = r.value_counts()
counts
# Out:
# Customer Care Call    1119
# Internet              1105
# Name: Received Via, dtype: int64

# %%
percent = r.value_counts( normalize = True)
percent
# Out:
# Customer Care Call    0.503147
# Internet              0.496853
# Name: Received Via, dtype: float64

# %%
percent100 = percent.mul(100).round(1).astype(str) +'%'
percent100
# Out:
# Customer Care Call    50.3%
# Internet              49.7%
# Name: Received Via, dtype: object
